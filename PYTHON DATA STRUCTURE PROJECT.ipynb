# %%
print("Press 1 to perform list operation:")
print("Press 2 to perform dictionary operation:")
print("Press 3 to perform set operation:")
print("Press 4 to perform string operation:")
print("Press 5 to perform tuple operation:")
print("\n")
ch1 = int(input("Enter the number to perform datatype operation: "))
abc = "*"
print(abc*75)
if ch1 == 1: 
    l = list(eval(input("Create a list : ")))
    print(abc*75)
    print("Press 1 for Addition operation:")
    print("Press 2 for deletion operation:")
    print("Press 3 to know about list:")
    print("\n")
    ch2 = int(input("Enter the number to perform operation: "))
    print(abc*75)
    if ch2 == 1:
        print("Press 1 for 'append' method:")
        print("Press 2 for 'insert' method:")
        print("Press 3 for 'extend' method:")
        print("\n")
        ch3 = int(input("Enter the number to select method : "))
        print(abc*75)
        if ch3 == 1:
            a = eval(input("Add single value into list: "))
            l.append(a)
            print("Single value added into list:",l)
        elif ch3 == 2:
            a = eval(input("Add single value into list: "))
            b = int(input("Enter a location-index where you want to add new value: "))
            l.insert(b,a)
            print(abc*75)
            print("Add single value into list as per mentioned index:",l)
        elif ch3 == 3:
            print(abc*75)
            a = list(eval(input("Add multiple value into list:")))
            l.extend(a)
            print(abc*75)
            print("Multiple value added into list:",l)
        else:
            print("Sorry, wrong choice. Please enter correct choice between 1 to 3 to perform operation")
    elif ch2 == 2:
        print("Press 1 for remove method.")
        print("Press 2 for pop method.")
        print("Press 3 for clear method.")
        print("press 4 for delete method")
        print("\n")
        ch3 = int(input("Enter the number to select method."))
        print(abc*75)
        if ch3 == 1:
            a = eval(input("Enter a value you want to remove from the list : "))
            l.remove(a)
            print(abc*75)
            print("Value is removed :",l)
        elif ch3 == 2:
            a = int(input("Enter the index of value to remove value from list : "))
            l.pop(a)
            print(abc*70)
            print("Value is removed as per index location :",l)
        elif ch3 == 3:
            l.clear()
            print("All values are deleted from the list.",l," i.e. empty list")
        elif ch3 == 4:
            del l
            print("Whole list is deleted along with values.")
        else:
            print("Sorry, wrong choice. Please enter correct choice between 1 to 4 to perform operation")
    elif ch2 == 3:
        print(" A list is a data structure in Python that is a mutable or changeable, heterogeneous and ordered sequence of elements. \n The items in the list are separated with the comma (,) and enclosed with the square brackets [].")
    else:
        print("Sorry, wrong choice. Please enter correct choice between 1 to 3 to perform operation")
elif ch1 == 2:
    d = dict(eval(input("Create the dictionary: ")))
    print(abc*75)
    print("Press 1 for Addition operation:")
    print("Press 2 for deletion operation:")
    print("Press 3 to access the data of dictionary:")
    print("Press 4 to know about dictionary.")
    print("\n")
    ch2 = int(input("Enter the number to perform operation : "))
    print(abc*75)
    if ch2 == 1:
        print("Press 1 for add values using key:")
        print("Press 2 for update method:")
        print("\n")
        ch3 = int(input("Enter the number to select the addition method: "))
        if ch3 == 1:
            a = eval(input("enter name of key: "))
            b = eval(input("Enter value of key: "))
            d[a]=b
            print("Addition operation performed:",d)
        elif ch3 == 2:
            a = dict(eval(input("Enter the multiple key value pair in dictionary format : ")))
            d.update(a)
            print("Update operation performed :",d)
        else:
            print("Sorry, wrong choice. Please enter correct choice between 1 to 2 to perform operation")
    elif ch2 == 2:
        print("Press 1 for the delete method:")
        print("Press 2 for the pop method:")
        print("Press 3 for the popitems method:")
        print("Press 4 for the clear method:")
        print("\n")
        ch3 = int(input("Enter the number for the method : "))
        print(abc*75)
        if ch3 == 1:
            del d
            print("Whole dictionary is delted with keys and values")
        elif ch3 == 2:
            a = eval(input("Enter the key of record which you want to delete from dictionary : "))
            d.pop(a)
            print("Pop operation executed",d)
        elif ch3 == 3:
            d.popitem()
            print("Popitem operation executed",d)
        elif ch3 == 4:
            d.clear()
            print("Keys and values of Dictionary are deleted",d," i.e. empty dictionary")
        else:
            print("Sorry, wrong choice. Please enter correct choice between 1 to 4 to perform operation")
    elif ch2 == 3:
        print("Press 1 to access all the keys of dictionary.")
        print("Press 2 to access all the values of dictionary.")
        print("Press 3 to access value of perticular key based on key name.")
        print("Press 4 to access all key-value pair of dictionary.")
        print("\n")
        ch3 = int(input("Enter the number to perform operation : "))
        print(abc*75)
        if ch3 == 1:
            a = d.keys()
            print("All keys of dictionary are :",a)
        elif ch3 == 2:
            a = d.values()
            print("All values of dictionary are :",a)
        elif ch3 == 3:
            k = eval(input("Enter a key name whose value is to be access : "))
            a = d.get(k)
            print(abc*75)
            print(f"Value of the key {k} is :",a)
        elif ch3 == 4:
            a = d.items()
            print("All key-value pairs of dictionary are :",a)
        else:
            print("Sorry, wrong choice. Please enter correct choice between 1 to 4 to perform operation")
    elif ch2 == 4:
        print(" Dictionary is a mutabble or changeable key-value pairs. \n Dictionary is ordered and heterogenous. \n In dictionary we can only change the values assigned to the keys and keys are immutable. \n Dictionary are enclosed in curly bracket {} and dictionary element are seperated by comma (,)")
    else:
        print("Sorry, wrong choice. Please enter correct choice between 1 to 4 to perform operation")
elif ch1 == 3:
    s = set(eval(input("Create the set : ")))
    print(abc*75)
    print("Press 1 for Addition operation.")
    print("Press 2 for deletion operation.")
    print("Press 3 to know about set.")
    print("\n")
    ch2 = int(input("Enter the choice for operation : "))
    print(abc*75)
    if ch2 == 1:
        print("Press 1 for 'add' method.")
        print("Press 2 for 'update' method.")
        print("\n")
        ch3 = int(input("Enter the number to perform operation: "))
        print(abc*75)
        if ch3 == 1:
            a = eval(input("Add single value in set : "))
            s.add(a)
            print(abc*7)
            print("Add operation executed:",s)
        elif ch3 == 2:
            a = list(eval(input("Add multiple value in set: ")))
            s.update(a)
            print(abc*75)
            print("Update operation executed:",s)
        else:
            print("Sorry, wrong choice. Please enter correct choice 1 or 2 to perform operation")
    elif ch2 == 2:
        print("Press 1 for pop method.")
        print("Press 2 for discard method.")
        print("Press 3 for remove method.")
        print("Press 4 for delete method.")
        print("\n")
        ch3 = int(input("Enter the number to select the method : "))
        print(abc*75)
        if ch3 == 1:
            s.pop()
            print("Pop operation executed:",s)
        elif ch3 == 2:
            a = eval(input("Enter the value which want to remove from the set : "))
            s.discard(a)
            print(abc*75)
            print("Discard operation executed:",s)
        elif ch3 == 3:
            a = eval(input("Enter the value which want to remove from the set : "))
            s.remove(a)
            print(abc*75)
            print("Remove operation executed:",s)
        elif ch3 == 4:
            del s
            print("Set is deleted along with values")
        else:
            print("Sorry, wrong choice. Please enter correct choice between 1 to 4 to perform operation")
    elif ch2 == 3:
        print(" Set is a unordered and contains only unique values. \n set is heterogenous and mutable collection of values. \n set are enclosed in round bracket () and set element are seperated by comma (,)")
    else:
        print("Sorry, wrong choice. Please enter correct choice between 1 to 3 to perform operation")
elif ch1 == 4:
    sti = str(input("Enter a string : "))
    print(abc*70)
    print("Press 1 to access the single elemnt using indexing.")
    print("Press 2 to access multiple element using slicing.")
    print("Press 3 to know about the string.")
    print("\n")
    ch2 = int(input("Enter the number to select method : "))
    print(abc*75)
    if ch2 == 1:
        b = int(input("Enter the index to access value index-wise: "))
        a = sti[b]
        print(abc*75)
        print(f"Value of index {b} is :",a)
    elif ch2 == 2:
        f = int(input("Enter the start index :"))
        e = int(input("Enter the end index : "))
        a = sti[f:e]
        print(abc*75)
        print("Slicing performed according to given indexes :",a)
    elif ch2 == 3:
        print("String is a group of character which include A-Z alphabets and special characters.")
    else:
        print("Sorry, wrong choice. Please enter correct choice between 1 to 3 to perform operation")
elif ch1 == 5:
    tup = tuple(eval(input("Create the tuple : ")))
    print(abc*75)
    print("Press 1 to access the single element using indexing.")
    print("Press 2 to access multiple element using slicing.")
    print("Press 3 to know about the tuple")
    print("\n")
    ch2 = int(input("Enter the choice to select method : "))
    print(abc*75)
    if ch2 == 1:
        b = int(input("Enter the index whose value is to be access : "))
        a = tup[b]
        print(abc*75)
        print(f"Value of index {b} is :",a)
    elif ch2 == 2:
        f = int(input("Enter start index :"))
        e = int(input("Enter end index : "))
        a = tup[f:e]
        print(abc*75)
        print("Slicing performed according to given indexes :",a)
    elif ch2 == 3:
        print(" Tuple is a ordered and heterogenous. \n Tuple are immutable group of elements. \n Tuple are enclosed in round bracket () and Tuple element are seperated by (,).")
    else:
        print("Sorry, wrong choice. Please enter correct choice between 1 to 3 to perform operation")
else:
    print("Sorry, wrong choice. Please enter correct choice between 1 to 5 to perform operation")
# Out:
# Press 1 to perform list operation:
# Press 2 to perform dictionary operation:
# Press 3 to perform set operation:
# Press 4 to perform string operation:
# Press 5 to perform tuple operation:
#
#
# Enter the number to perform datatype operation: 1
# ***************************************************************************
# Create a list : ['abhi','mandar']
# ***************************************************************************
# Press 1 for Addition operation:
# Press 2 for deletion operation:
# Press 3 to know about list:
#
#
# Enter the number to perform operation: 1
# ***************************************************************************
# Press 1 for 'append' method:
# Press 2 for 'insert' method:
# Press 3 for 'extend' method:
#
#
# Enter the number to select method : 1
# ***************************************************************************
# Add single value into list: 'hrithik'
# Single value added into list: ['abhi', 'mandar', 'hrithik']
